# %% [markdown]
# # Marianna Ghazaryan & Gurgen Hovakimyan

# %% [markdown]
# Dear Gevorg, in this example we use only a few functions of our project. For more information you can see our module and/or wait our presentation.
#
# Thank you.

# %%
import numpy as np
import pandas as pd
from numpy import dtype
import module as mg # our main module of functions

# %%
df = pd.read_csv('oil.csv')

# %%
df2 = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [np.nan, 2, 3, 4, 5, 6],
                   'zoo': [np.nan, 2, 3, np.nan, 5, np.nan]})

# %%
# normalization of dataset. By defualt we use z-score method. code bellow runs few minutes
mg.normalization(df)
# Out:
#             Date      Open      High       Low     Close  Vol    Weekday  \
# 0      10/1/2012  1.369186  1.385485  1.346295  1.343185    0     Monday
# 1      10/2/2012  1.342573  1.328970  1.338743  1.312619   -1    Tuesday
# 2      10/3/2012  1.312004  1.289014  1.209287  1.197188    0  Wednesday
# 3      10/4/2012  1.200158  1.332210  1.219716  1.341746    0   Thursday
# 4      10/5/2012  1.337897  1.343009  1.306020  1.333475    0     Friday
# 5      10/7/2012  1.332143  1.308452  1.355644  1.329520   -1     Sunday
# 6      10/8/2012  1.321714  1.319611  1.309616  1.336712    0     Monday
# 7      10/9/2012  1.345450  1.398803  1.356723  1.413306    0    Tuesday
# 8     10/10/2012  1.405149  1.426521  1.415697  1.410789    0  Wednesday
# 9     10/11/2012  1.414859  1.445959  1.436195  1.464369    0   Thursday
# 10    10/12/2012  1.466646  1.442719  1.424328  1.414385    0     Friday
# 11    10/14/2012  1.419894  1.399163  1.431160  1.405035   -1     Sunday
# 12    10/15/2012  1.403710  1.429401  1.407427  1.453941    0     Monday
# 13    10/16/2012  1.447226  1.443079  1.444465  1.426611    0    Tuesday
# 14    10/17/2012  1.434998  1.422921  1.419653  1.408272    0  Wednesday
# 15    10/18/2012  1.404430  1.398443  1.375422  1.380583    0   Thursday
# 16    10/19/2012  1.376019  1.385125  1.315369  1.304348    0     Friday
# 17    10/21/2012  1.288628  1.267775  1.308537  1.284570   -1     Sunday
# 18    10/22/2012  1.282514  1.302692  1.287320  1.285289    0     Monday
# 19    10/23/2012  1.274962  1.260576  1.222233  1.231709    0    Tuesday
# 20    10/24/2012  1.231446  1.244018  1.203893  1.214089    0  Wednesday
# 21    10/25/2012  1.213105  1.241858  1.227627  1.238901    0   Thursday
# 22    10/26/2012  1.240077  1.256976  1.225469  1.282053    0     Friday
# 23    10/28/2012  1.276040  1.260576  1.282646  1.263713   -1     Sunday
# 24    10/29/2012  1.262374  1.277135  1.265385  1.268748    0     Monday
# 25    10/30/2012  1.265251  1.271375  1.270419  1.258679    0    Tuesday
# 26    10/31/2012  1.259857  1.260576  1.257833  1.235305    0  Wednesday
# 27     11/1/2012  1.199438  1.191103  1.201736  1.202941   -1   Thursday
# 28     11/2/2012  1.193325  1.194342  1.131614  1.108727    0     Friday
# 10     Oct    -1
# 11     Oct    -1
# 12     Oct    -1
# 13     Oct    -1
# 14     Oct    -1
# 15     Oct    -1
# 16     Oct    -1
# 17     Oct    -1
# 18     Oct    -1
# 19     Oct    -1
# 20     Oct    -1
# 21     Oct    -1
# 22     Oct    -1
# 23     Oct    -1
# 24     Oct    -1
# 25     Oct    -1
# 26     Oct    -1
# 27     Nov    -1
# 28     Nov    -1
# 29     Nov    -1
# ...    ...   ...
# 1613   Dec     1
# 1614   Dec     1
# 1615   Dec     1
# 1616   Dec     1
# 1617   Dec     1
# 1618   Jan     1
# 1619   Jan     1
# 1620   Jan     1
# 1621   Jan     1
# 1622   Jan     1
# 1623   Jan     1
# 1624   Jan     1
# 1625   Jan     1
# 1626   Jan     1
# 1627   Jan     1
# 1628   Jan     1
# 1629   Jan     1
# 1630   Jan     1
# 1631   Jan     1
# 1632   Jan     1
# 1633   Jan     1
# 1634   Jan     1
# 1635   Jan     1
# 1636   Jan     1
# 1637   Jan     1
# 1638   Jan     1
# 1639   Jan     1
# 1640   Jan     1
# 1641   Jan     1
# 1642   Jan     1
#
# [1643 rows x 9 columns]

# %%
# Fill nan values of defind column
mg.nafill(df2, 'baz')
# Out:
# C:\Users\Gurgen\Desktop\Master Degree\1 course\1 half\Python\Group_Project\Marianna_Gurgen_github\pythondatamanipulation\final project\module.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[columns[i]][j] = df[columns[i]].mean()
#    foo bar  baz  zoo
# 0  one   A  4.0  NaN
# 1  one   B  2.0  2.0
# 2  one   C  3.0  3.0
# 3  two   A  4.0  NaN
# 4  two   B  5.0  5.0
# 5  two   C  6.0  NaN

# %%
# drop columns with na
mg.dropna(df2)
# Out:
# array([['one', 'B', 2.0, 2.0],
#        ['one', 'C', 3.0, 3.0],
#        ['two', 'B', 5.0, 5.0]], dtype=object)

# %%
mg.summary(df)
# Out:
# Date
# Count :  1643
# Unique :  1643
#
#
# Open
# Count :  1643
# Min :  27.99
# 1st Q :  49.925
# Median :  61.68
# 3rd Q :  106.97
# Max :  117.96
# Mean :  74.06831405964707
# St. dev :  27.80608273465092
#
#
# High
# Count :  1643
# Min :  28.75
# 1st Q :  50.67
# Median :  62.7
# 3rd Q :  107.845
# Max :  118.29
# Mean :  74.78076080340847
# St. dev :  27.780344052611788
#
#
# Low
# Count :  1643
# Min :  27.1
# 1st Q :  49.25
# Median :  60.63
# 3rd Q :  106.455
# Max :  117.74
# Mean :  73.32127814972615
# St. dev :  27.808711385783646
#
#
# Close
# Count :  1643
# Min :  27.79
# 1st Q :  49.92
# Median :  61.87
# 3rd Q :  107.03
# Max :  118.04
# Mean :  74.04758368837497
# St. dev :  27.808848624480497
#
#
# Vol
# Count :  1643
# Min :  0
# 1st Q :  48471.5
# Median :  113728.0
# 3rd Q :  159089.0
# Max :  522586
# Mean :  108013.22458916616
# St. dev :  72296.2539506527
#
#
# Weekday
# Count :  1643
# Unique :  6
#
#
# Month
# Count :  1643
# Unique :  12
#
#
# Year
# Count :  1643
# Min :  2012
# 1st Q :  2014.0
# Median :  2015.0
# 3rd Q :  2016.0
# Max :  2018
# Mean :  2014.900182592818
# St. dev :  1.5591523715387525

# %%
# calculate the difference between two variables or one variable change dynamics
a = mg.change(df, "Open", "Close", symmetry_type = 'symmetric', difference_type = 'logarithmic')
print(a[:10])
# Out:
# [-0.0066207632023428204, -0.007659420189728447, -0.029466540554772463, 0.03583564437112733, -0.001258992972053974, -0.0008103363339021316, 0.003602958320214292, 0.016635174339790504, 0.0012366400303999987, 0.011920554865337928]

# %%
# returns pivot for specified columns
mg.pivoting(df, "Date", "Weekday", "Open")
# Out:
# array([[112.14, 0, 0, 0, 0, 0],
#        [0, 111.4, 0, 0, 0, 0],
#        [0, 0, 110.55, 0, 0, 0],
#        ...,
#        [0, 0, 70.18, 0, 0, 0],
#        [0, 0, 0, 70.09, 0, 0],
#        [0, 0, 0, 0, 69.01, 0]], dtype=object)

# %%
# returns pivot table grouped by columns and aggregated by specified function
mg.pivvottable(df, "Month", "Weekday", "Open", function = "median")
# Out:
# array([[60.95 , 64.   , 59.08 , 62.88 , 64.13 , 60.98 ],
#        [52.135, 52.2  , 52.325, 52.395, 51.66 , 51.515],
#        [63.35 , 63.58 , 63.43 , 62.81 , 62.93 , 62.64 ],
#        [59.735, 58.56 , 58.985, 58.035, 58.98 , 58.925],
#        [62.995, 56.96 , 62.305, 68.52 , 61.8  , 66.54 ],
#        [56.165, 57.65 , 55.785, 57.44 , 57.675, 58.8  ],
#        [63.34 , 63.905, 63.965, 63.62 , 63.32 , 64.69 ],
#        [58.11 , 57.85 , 60.05 , 56.33 , 56.13 , 56.04 ],
#        [66.75 , 65.82 , 65.855, 67.17 , 65.6  , 66.16 ],
#        [74.965, 63.68 , 63.52 , 70.46 , 64.12 , 63.355],
#        [72.575, 60.38 , 57.95 , 83.36 , 85.13 , 86.1  ],
#        [54.915, 56.19 , 55.59 , 55.02 , 54.625, 54.18 ]])

# %%
# groupping and aggregating by specified column and function
mg.grouppby(df, 'Month', function = "minimum")
# Out:
# ['Open', 'High', 'Low', 'Close', 'Vol', 'Year']
# Oct [46.91, 47.57, 46.41, 47.03, 40, 2012]
# Nov [43.97, 44.52, 43.16, 43.99, 3, 2012]
# Dec [36.36, 36.72, 35.98, 36.23, 5, 2012]
# Jan [27.99, 28.75, 27.1, 27.79, 1, 2013]
# Feb [30.83, 31.35, 29.92, 30.81, 7, 2013]
# Mar [36.6, 37.25, 35.95, 36.6, 12, 2013]
# Apr [37.5, 38.44, 37.27, 37.58, 23, 2013]
# May [43.49, 45.7, 43.33, 43.45, 0, 2013]
# Jun [44.81, 45.75, 44.35, 44.78, 14, 2013]
# Jul [43.11, 43.38, 42.52, 43.16, 74, 2013]
# Aug [41.94, 43.18, 41.51, 41.97, 21, 2013]
# Sep [45.79, 46.27, 45.09, 45.82, 40, 2013]
